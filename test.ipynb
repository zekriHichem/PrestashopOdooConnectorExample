# %% [markdown]
# # Briefing Test Technique Final / Dév. web FARIMER

# %% [markdown]
# ## prestashop connection
# Show All products (id , name, price )

# %%
# import Libs
from prestapyt import PrestaShopWebServiceDict
#--------------------------------------------------------------------------------------------------------------------

connection_prestashop = PrestaShopWebServiceDict("http://localhost:8080/api", "HQI1D7D617ATKY2AAAVCC7PECYF2LCGX")
products_prstashop = connection_prestashop.get("products")['products']['product']
for product in products_prstashop : 
    id_prod = product['attrs']['id']
    prods = connection_prestashop.get("products", id_prod)
    print( "id = " + prods['product']['id'] )
    print( "price = " + prods['product']['price'] + "$" )
    print( "name = " + prods['product']['name']['language']['value'] )
    print( "---------------------------------------" )
# Out:
# C:\Users\TRETEC\Anaconda3\lib\site-packages\prestapyt\prestapyt.py:220: UserWarning: This library may not be compatible with this version of PrestaShop (1.7.6.8). Please upgrade/downgrade this library
#   "Please upgrade/downgrade this library") % (version,))
# id = 22
# price = 2000.000000$
# name = myproductnew
# ---------------------------------------
# id = 20
# price = 20000.000000$
# name = hicham
# ---------------------------------------
# id = 21
# price = 0.000000$
# name =
# ---------------------------------------
# id = 1
# price = 23.900000$
# name = T-shirt imprimé colibri
# ---------------------------------------
# id = 2
# price = 35.900000$
# name = Pull imprimé colibri
# ---------------------------------------
# id = 16
# price = 12.900000$
# name = Carnet de notes Renard
# ---------------------------------------
# id = 17
# price = 12.900000$
# name = Carnet de notes Ours brun
# ---------------------------------------
# id = 18
# price = 12.900000$
# name = Carnet de notes Colibri
# ---------------------------------------
# id = 6
# price = 11.900000$
# name = Mug The best is yet to come
# ---------------------------------------
# id = 7
# price = 11.900000$
# name = Mug The adventure begins
# ---------------------------------------
# id = 8
# price = 11.900000$
# name = Mug Today is a good day
# ---------------------------------------
# id = 9
# price = 18.900000$
# name = Coussin renard
# ---------------------------------------
# id = 10
# price = 18.900000$
# name = Coussin ours brun
# ---------------------------------------
# id = 11
# price = 18.900000$
# name = Coussin colibri
# ---------------------------------------
# id = 15
# price = 35.000000$
# name = Pack Mug + Affiche encadrée
# ---------------------------------------
# id = 19
# price = 13.900000$
# name = Mug personnalisable
# ---------------------------------------
# id = 3
# price = 29.000000$
# name = Affiche encadrée The best is yet to come
# ---------------------------------------
# id = 4
# price = 29.000000$
# name = Affiche encadrée The adventure begins
# ---------------------------------------
# id = 5
# price = 29.000000$
# name = Affiche encadrée Today is a good day
# ---------------------------------------
# id = 12
# price = 9.000000$
# name = Illustration vectorielle Renard
# ---------------------------------------
# id = 13
# price = 9.000000$
# name = Illustration vectorielle Ours brun
# ---------------------------------------
# id = 14
# price = 9.000000$
# name = Illustration vectorielle Colibri
# ---------------------------------------

# %% [markdown]
# ## Odoo Connection
# Show All products (id , price, name)

# %%
#import Libs
import erppeek
#----------------------------------------------------------------------------------------------------------

connection_odoo = erppeek.Client( "http://localhost:8069", "zekri", "hsmz.zekri@gmail.com", "odoo" ) 
products_odoo = connection_odoo.model("product.product")
products_ids_odoo = products_odoo.search([])
for pid in products_ids_odoo :
    print("--------------------------------------------------------")
    print("id = " + str(con.read("product.product",[pid])[0]['id']))
    print("price = " + str(con.read("product.product",[pid])[0]['lst_price']) + "DA")
    print("name = " + con.read("product.product",[pid])[0]['name'])
# Out:
# --------------------------------------------------------
# id = 15
# price = 800.4DA
# name = Customizable Desk (CONFIG)
# --------------------------------------------------------
# id = 37
# price = 750.0DA
# name = Customizable Desk (CONFIG)
# --------------------------------------------------------
# id = 38
# price = 750.0DA
# name = Customizable Desk (CONFIG)
# --------------------------------------------------------
# id = 36
# price = 150.0DA
# name = Deposit
# --------------------------------------------------------
# id = 16
# price = 147.0DA
# name = Corner Desk Right Sit
# --------------------------------------------------------
# id = 17
# price = 320.0DA
# name = Large Cabinet
# --------------------------------------------------------
# id = 18
# price = 79.0DA
# name = Storage Box
# --------------------------------------------------------
# id = 19
# price = 1799.0DA
# name = Large Desk
# --------------------------------------------------------
# id = 20
# price = 47.0DA
# name = Pedal Bin
# --------------------------------------------------------
# id = 21
# price = 14.0DA
# name = Cabinet with Doors
# --------------------------------------------------------
# id = 23
# price = 16.5DA
# name = Conference Chair (CONFIG)
# --------------------------------------------------------
# id = 24
# price = 22.900000000000002DA
# name = Conference Chair (CONFIG)
# --------------------------------------------------------
# id = 2
# price = 400.0DA
# name = Hotel Accommodation
# --------------------------------------------------------
# id = 1
# price = 14.0DA
# name = Restaurant Expenses
# --------------------------------------------------------
# id = 12
# price = 750.0DA
# name = Customizable Desk (CONFIG)
# --------------------------------------------------------
# id = 13
# price = 750.0DA
# name = Customizable Desk (CONFIG)
# --------------------------------------------------------
# id = 14
# price = 800.4DA
# name = Customizable Desk (CONFIG)
# --------------------------------------------------------
# id = 25
# price = 12.5DA
# name = Office Chair Black
# --------------------------------------------------------
# id = 30
# price = 885.0DA
# name = Individual Workplace
# --------------------------------------------------------
# id = 26
# price = 85.0DA
# name = Corner Desk Black
# --------------------------------------------------------
# id = 31
# price = 2950.0DA
# name = Acoustic Bloc Screens
# --------------------------------------------------------
# id = 34
# price = 40000.0DA
# name = Large Meeting Table
# --------------------------------------------------------
# id = 5
# price = 70.0DA
# name = Office Chair
# --------------------------------------------------------
# id = 8
# price = 450.0DA
# name = Desk Combination
# --------------------------------------------------------
# id = 29
# price = 2100.0DA
# name = Desk Stand with Screen
# --------------------------------------------------------
# id = 33
# price = 23500.0DA
# name = Four Person Desk
# --------------------------------------------------------
# id = 32
# price = 3645.0DA
# name = Drawer
# --------------------------------------------------------
# id = 6
# price = 40.0DA
# name = Office Lamp
# --------------------------------------------------------
# id = 27
# price = 25.0DA
# name = Drawer Black
# --------------------------------------------------------
# id = 35
# price = 60000.0DA
# name = Three-Seat Sofa
# --------------------------------------------------------
# id = 28
# price = 1950.0DA
# name = Flipover
# --------------------------------------------------------
# id = 7
# price = 280.0DA
# name = Office Design Software
# --------------------------------------------------------
# id = 40
# price = 20.0DA
# name = Warranty
# --------------------------------------------------------
# id = 41
# price = 38.0DA
# name = Warranty
# --------------------------------------------------------
# id = 4
# price = 38.25DA
# name = Virtual Home Staging
# --------------------------------------------------------
# id = 3
# price = 30.75DA
# name = Virtual Interior Design
# --------------------------------------------------------
# id = 42
# price = 10000.0DA
# name = hicham
# --------------------------------------------------------
# id = 43
# price = 200001.0DA
# name = mynewprod
# --------------------------------------------------------
# id = 44
# price = 200001.0DA
# name = mynewprod3

# %% [markdown]
# ## Add New product to Prestashop

# %%
blank_product = prestashop.get('products', options={'schema': 'blank'});
blank_product['product']['price'] = "2000"
blank_product['product']['name']['language']['value'] = "myproductnew"

prestashop.add("products",blank_product)
# Out:
# {'prestashop': {'product': {'id': '23',
#    'id_manufacturer': '',
#    'id_supplier': '',
#    'id_category_default': '',
#    'new': '',
#    'cache_default_attribute': '',
#    'id_default_image': {'attrs': {'notFilterable': 'true'}, 'value': ''},
#    'id_default_combination': {'attrs': {'notFilterable': 'true'}, 'value': ''},
#    'id_tax_rules_group': '',
#    'position_in_category': {'attrs': {'notFilterable': 'true'}, 'value': '1'},
#    'manufacturer_name': {'attrs': {'notFilterable': 'true'}, 'value': ''},
#    'quantity': {'attrs': {'notFilterable': 'true'}, 'value': ''},
#    'type': {'attrs': {'notFilterable': 'true'}, 'value': 'simple'},
#    'id_shop_default': '1',
#    'reference': '',
#    'supplier_reference': '',
#    'location': '',
#    'width': '',
#    'height': '',
#    'depth': '',
#    'weight': '',
#    'quantity_discount': '',
#    'ean13': '',
#    'isbn': '',
#    'upc': '',
#    'cache_is_pack': '',
#    'cache_has_attachments': '',
#    'is_virtual': '',
#    'state': '',
#    'additional_delivery_times': '',
#    'delivery_in_stock': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'delivery_out_stock': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'on_sale': '',
#    'online_only': '',
#    'ecotax': '',
#    'minimal_quantity': '',
#    'low_stock_threshold': '',
#    'low_stock_alert': '',
#    'price': '2000',
#    'wholesale_price': '',
#    'unity': '',
#    'unit_price_ratio': '',
#    'additional_shipping_cost': '',
#    'customizable': '',
#    'text_fields': '',
#    'uploadable_files': '',
#    'active': '',
#    'redirect_type': '',
#    'id_type_redirected': '',
#    'available_for_order': '',
#    'available_date': '',
#    'show_condition': '',
#    'condition': 'new',
#    'show_price': '',
#    'indexed': '',
#    'visibility': 'both',
#    'advanced_stock_management': '',
#    'date_add': '2020-10-01 23:04:41',
#    'date_upd': '2020-10-01 23:04:41',
#    'pack_stock_type': '',
#    'meta_description': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'meta_keywords': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'meta_title': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'link_rewrite': {'language': {'attrs': {'id': '1'},
#      'value': 'myproductnew'}},
#    'name': {'language': {'attrs': {'id': '1'}, 'value': 'myproductnew'}},
#    'description': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'description_short': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'available_now': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'available_later': {'language': {'attrs': {'id': '1'}, 'value': ''}},
#    'associations': {'categories': {'attrs': {'nodeType': 'category',
#       'api': 'categories'},
#      'value': ''},
#     'images': {'attrs': {'nodeType': 'image', 'api': 'images'}, 'value': ''},
#     'combinations': {'attrs': {'nodeType': 'combination',
#       'api': 'combinations'},
#      'value': ''},
#     'product_option_values': {'attrs': {'nodeType': 'product_option_value',
#       'api': 'product_option_values'},
#      'value': ''},
#     'product_features': {'attrs': {'nodeType': 'product_feature',
#       'api': 'product_features'},
#      'product_feature': {'id': '0', 'id_feature_value': '0'}},
#     'tags': {'attrs': {'nodeType': 'tag', 'api': 'tags'}, 'tag': {'id': '0'}},
#     'stock_availables': {'attrs': {'nodeType': 'stock_available',
#       'api': 'stock_availables'},
#      'stock_available': {'id': '62', 'id_product_attribute': '0'}},
#     'accessories': {'attrs': {'nodeType': 'product', 'api': 'products'},
#      'value': ''},
#     'product_bundle': {'attrs': {'nodeType': 'product', 'api': 'products'},
#      'value': ''}}}}}

# %% [markdown]
# ## Add New product to Odoo

# %%
connection_odoo.create("product.product",{'name' : 'mynewprod3', 'lst_price' : '200001' })
# Out:
# 44

# %% [markdown]
# ## Connector Odoo and Prestashop

# %%
def from_odoo_to_prestashop(connection_odoo, connection_prestashop, id_product) : 
    # get product from odoo
    products_odoo = connection_odoo.model("product.product")
    product = read("product.product",[id_product])[0]
    # create blank product 
    blank_product = prestashop.get('products', options={'schema': 'blank'});
    blank_product['product']['price'] = product['lst_price']
    blank_product['product']['name']['language']['value'] = product['name']
    # add it on prestashop
    return connection_prestashop.add("products",blank_product)['prestashop']['product']['id']

# %%
def from_prestashop_to_odoo(connection_odoo, connection_prestashop, id_product):
    # get product from prestashop
    product = connection_prestashop.get("products", id_product)
    # create it on odoo
    return connection_odoo.create("product.product", 
                                  {'name': prods['product']['name']['language']['value'], 
                                   'lst_price' : prods['product']['price'] })

# %%
def get_all_products_odoo(connection_odoo) :
    connection_odoo = erppeek.Client( "http://localhost:8069", "zekri", "hsmz.zekri@gmail.com", "odoo" ) 
    products_odoo = connection_odoo.model("product.product")
    products_ids_odoo = products_odoo.search([])
    products = []
    for pid in products_ids_odoo :
        prod = connection_odoo.read("product.product",[pid])[0]
        product = {'id' : prod['id'] , 'name':prod['name'] , 'price': prod['lst_price']}
        products.append(product)
    return products

# %%
def get_all_products_prestashop(connection_prestashop) :
        products_prstashop = connection_prestashop.get("products")['products']['product']
        products = []
        for product in products_prstashop : 
            id_prod = product['attrs']['id']
            prod = connection_prestashop.get("products", id_prod)
            product = {'id' : prod['product']['id'],
                       'name':prod['product']['name']['language']['value'],
                       'price': prod['product']['price']}
            products.append(product)
        return products

# %%
def get_one_product_odoo(connection_odoo, id_prod):
        prod = connection_odoo.read("product.product",[id_prod])[0]
        product = {'id' : prod['id'] , 'name':prod['name'] , 'price': prod['lst_price']}
        return product

# %%
def get_one_product_prestashop(connection_prestashop, id_prod):
            prod = connection_prestashop.get("products", id_prod)
            product = {'id' : prod['product']['id'],
                       'name':prod['product']['name']['language']['value'],
                       'price': prod['product']['price']}
            return product
